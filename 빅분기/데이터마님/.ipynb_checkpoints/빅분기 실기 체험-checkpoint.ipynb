# %%
# 출력을 원할 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

import pandas as pd

df = pd.read_csv("data/mtcars.csv")

# 사용자 코딩

import numpy as np
print(np.array(df['qsec']))

np.array(df['qsec']).reshape(-1,1)

import sklearn
print(sklearn.__all__)
import sklearn.preprocessing
print(dir(sklearn.preprocessing))
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
print(scaler.fit_transform(np.array(df['qsec']).reshape(-1,1)))

scaled = scaler.fit_transform(np.array(df['qsec']).reshape(-1,1))

print(sum((scaled > 0.5) * 1))

# 해당 화면에서는 제출하지 않으며, 문제 풀이 후 답안제출에서 결괏값 제출

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

import pandas as pd

train = pd.read_csv("data/customer_train.csv")
test = pd.read_csv("data/customer_test.csv")

# 사용자 코딩
print(train.isnull().sum())
print(test.isnull().sum())
print(train.nunique())
print(test.nunique())

train['환불금액'] = train['환불금액'].fillna(train['환불금액'].mean())
test['환불금액'] = test['환불금액'].fillna(test['환불금액'].mean())

print(train.isnull().sum())
print(test.isnull().sum())
x = train.drop(columns = ['회원ID','성별'])
test_x = test.drop(columns = ['회원ID'])

x_dummies = pd.get_dummies(x)
test_x_dummies = pd.get_dummies(test_x)

print(len(x_dummies.columns))
print(len(test_x_dummies.columns))
test_x_dummies = test_x_dummies.reindex(columns = x_dummies.columns, fill_value = 0)
print(len(test_x_dummies.columns))

y = train['성별']

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# import sklearn
# print(sklearn.__all__)
# print(dir(sklearn.ensemble))

X_train, X_valid, Y_train, Y_valid = train_test_split(x_dummies, y, stratify = y, random_state = 42)
rf = RandomForestClassifier(random_state = 42)
rf.fit(X_train,Y_train)
print(rf.predict_proba(X_valid)[:,1])
predict_valid_proba = rf.predict_proba(X_valid)[:,1]

from sklearn.metrics import roc_auc_score
print(roc_auc_score(Y_valid,predict_valid_proba))

predict_test_proba = rf.predict(test_x_dummies)
print(predict_test_proba)

pd.DataFrame({'pred':predict_test_proba}).to_csv("result.csv", index=False)

reselt = pd.read_csv("result.csv")
print(reselt)

# 답안 제출 참고
# 아래 코드는 예시이며 변수명 등 개인별로 변경하여 활용
# pd.DataFrame변수.to_csv("result.csv", index=False)

# %% [markdown]
# https://yensr.tistory.com/49
# <br>
# https://wotres.tistory.com/entry/%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1-%ED%9A%8C%EA%B7%80logistic-regression-in-python
# <br>
# https://3months.tistory.com/28
# <br>
# https://signature95.tistory.com/45

# %%
# 출력을 원할 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

import pandas as pd

df = pd.read_csv("data/Titanic.csv")

# 사용자 코딩
print(pd.crosstab(df['Gender'],df['Survived']))
data = pd.crosstab(df['Gender'],df['Survived'])

import scipy
print(scipy.__all__)
import scipy.stats
print(dir(scipy.stats))
from scipy.stats import chi2_contingency

print(help(chi2_contingency))
chi2, p, dof, expected = chi2_contingency(data)
print(chi2, p, dof, expected)
print(round(chi2,3)) # 1번 정답


print(df.isnull().sum())
print(df['Gender'])
df['Gender'] = df['Gender'].map({'male':1,'female':0})
print(df['Gender'])


# from sklearn.linear_model import LogisticRegression
# lr = LogisticRegression()
# lr.fit(df[['Gender','SibSp','Parch','Fare']],df['Survived'])
# print(lr.score(df[['Gender','SibSp','Parch','Fare']],df['Survived'])) #정확도
# print(dir(lr))
# print(lr.coef_) # 피쳐들의 계수 (기울기)   , .lr.intercept_ # 절편 
# print(lr.coef_[0][2])
# print(round(lr.coef_[0][2],3)) # 2번 정답


import statsmodels.api as sm

# logit = sm.Logit(df['Survived'],df[['Gender','SibSp','Parch','Fare']])
# result = logit.fit()
# print(result.summary())
# print(round(result.params.SibSp,3)) # 2번 정답

X = sm.add_constant(df[['Gender','SibSp','Parch','Fare']])
logit = sm.Logit(df['Survived'],X)
result = logit.fit()
print(result.summary())
print(round(result.params.SibSp,3)) # 2번 정답


import numpy as np
print(np.exp(result.params))
print(round(np.exp(result.params.SibSp),3)) # 3번 정답


# 해당 화면에서는 제출하지 않으며, 문제 풀이 후 답안제출에서 결괏값 제출
